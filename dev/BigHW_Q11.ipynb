# %% [markdown]
# # Question 11: A few unix commands

# %% [markdown]
# <style type="text/css">
#     ol { list-style-type: lower-alpha; }
# </style>
#
# 1.
# ```[bash]
# λ MATH2504 >> mkdir ./hw_q11
# λ MATH2504 >> cd ./hw_q11
# λ hw_q11 >> pwd
# /home/michael/uni/MATH2504/hw_q11
# ```
#
# 2.
# ```[bash]
# λ hw_q11 >> echo Michael Kasumagic
# Michael Kasumagic
# ```
#
# 3.
# ```[bash]
# λ hw_q11 >> echo Michael Kasumagic > my_name.txt
# ```
#
# 4.
# ```[bash]
# λ hw_q11 >> cat ./my_name.txt
# Michael Kasumagic
# ```
#
# 5.
# ```[bash]
# λ hw_q11 >> man ls  # took me a while to realise I needed the -l flag
# λ hw_q11 >> ls -l
# .rw-r--r-- 18 michael 19 Aug 23:44 my_name.txt
# ```
#
# 6.
# ```[bash]
# λ hw_q11 >>  cp ./my_name.txt ./my_name2.txt
# λ hw_q11 >> ls
# my_name.txt  my_name2.txt
# ```
#
# 7.
# ```[bash]
# λ hw_q11 >> mkdir ./people
# λ hw_q11 >> ls
# my_name.txt  my_name2.txt  people
# ```
#
# 8.
# ```[bash]
# λ hw_q11 >> mv ./my_name2.txt ./people/Michael_Kasumagic.txt
# λ hw_q11 >> ls -R
# my_name.txt  people
#
# ./people:
# Michael_Kasumagic.txt
# ```
#
# 9.
# ```[bash]
# λ hw_q11 >> echo Sam Altman > ./people/Sam_Altman.txt
# λ hw_q11 >> echo Mark Zuckerburg > ./people/Mark_Zuckerburg.txt
# λ hw_q11 >> echo Elon Musk > ./people/Elon_Musk.txt
# λ hw_q11 >> ls -R
# my_name.txt  people
#
# ./people:
# Elon_Musk.txt        Michael_Kasumagic.txt
# Mark_Zuckerburg.txt  Sam_Altman.txt
# ```
#
# 10.
# ```[bash]
# λ hw_q11 >> cd ./people/
# λ people >> mv ./Michael_Kasumagic.txt ../Michael_Kasumagic.txt
# λ people >> ls ./.. -R
# Michael_Kasumagic.txt  my_name.txt  people
#
# ./../people:
# Elon_Musk.txt  Mark_Zuckerburg.txt  Sam_Altman.txt
# ```
#
# 11.
# ```[bash]
# λ people >> mv ../Michael_Kasumagic.txt /home/michael/uni/MATH2504/hw_q11/people/Mi
# chael_Kasumagic.txt
# λ people >> ls
# Elon_Musk.txt        Michael_Kasumagic.txt
# Mark_Zuckerburg.txt  Sam_Altman.txt
# ```
#
# 12.
# ```[bash]
# λ people >> cp ./Elon_Musk.txt ./.Elon_Musk.txt
# λ people >> ls
# Elon_Musk.txt        Michael_Kasumagic.txt
# Mark_Zuckerburg.txt  Sam_Altman.txt
# ```
#
# 13.
# ```[bash]
# λ people >> ls -l -a
# .rw-r--r-- 10 michael 20 Aug 00:00 .Elon_Musk.txt
# .rw-r--r-- 10 michael 19 Aug 23:56 Elon_Musk.txt
# .rw-r--r-- 16 michael 19 Aug 23:55 Mark_Zuckerburg.txt
# .rw-r--r-- 18 michael 19 Aug 23:50 Michael_Kasumagic.txt
# .rw-r--r-- 11 michael 19 Aug 23:55 Sam_Altman.txt
# ```
#
# 14.
# ```[bash]
# λ people >> rm -rf /
# ```
# WHOOPS! give me a sec... Ok and we're back
# ```[bash]
# λ people >> rm -rf ./*
# λ people >> ls -l -a
# ```
#
# 15.
# ```[bash]
# λ hw_q11 >> rmdir ./people  # or rm -d ./people
# λ hw_q11 >> ls
# my_name.txt
# ```
